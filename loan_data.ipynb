# %% [markdown]
# <a href="https://colab.research.google.com/github/jiwoo-coding/Codingtest_Study/blob/main/loan_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install poppler-utils

# %%
# !pip install pdf2image

# %%
# pdf2image 라이브러리 임포트
from pdf2image import convert_from_path

# %%
# 로컬 내 PDF 파일 경로 변수로 지정
FILE_NAME = "sample_data/loan_sample.pdf"

# %%
FILE_NAME
# Out:
# 'sample_data/loan_sample.pdf'

# %%
# `convert_from_path` 함수 통해 PDF 파일 읽어와 이미지 리스트로 변환
images = convert_from_path(FILE_NAME)

# %%
len(images)
# Out:
# 52

# %%
# 변환된 이미지 확인
images[1]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1653x2337>

# %%
# 다음 단계를 위해 이미지 파일 로컬에 저장
for i, image in enumerate(images):
    image.save(f"page_{str(i)}.jpg", "JPEG")

# %%
# Out:
# page_0.jpg   page_17.jpg  page_24.jpg  page_31.jpg  page_39.jpg  page_46.jpg  page_6.jpg
# page_10.jpg  page_18.jpg  page_25.jpg  page_32.jpg  page_3.jpg   page_47.jpg  page_7.jpg
# page_11.jpg  page_19.jpg  page_26.jpg  page_33.jpg  page_40.jpg  page_48.jpg  page_8.jpg
# page_12.jpg  page_1.jpg   page_27.jpg  page_34.jpg  page_41.jpg  page_49.jpg  page_9.jpg
# page_13.jpg  page_20.jpg  page_28.jpg  page_35.jpg  page_42.jpg  page_4.jpg   sample_data/
# page_14.jpg  page_21.jpg  page_29.jpg  page_36.jpg  page_43.jpg  page_50.jpg
# page_15.jpg  page_22.jpg  page_2.jpg   page_37.jpg  page_44.jpg  page_51.jpg
# page_16.jpg  page_23.jpg  page_30.jpg  page_38.jpg  page_45.jpg  page_5.jpg
